# %%
pip install medigan
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.9/52.9 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 39.9 MB/s eta 0:00:00
# ...
#   Created wheel for medigan: filename=medigan-1.0.0-py3-none-any.whl size=58584 sha256=58ed3b0cf5c8607139ad70bf25b04eddbd381032210f4442cadfe6a0f1a9bc8b
#   Stored in directory: /root/.cache/pip/wheels/40/db/d6/78c736ec5a682197ecc17266e95d2f8016be60fcb9ee57bb87
# Successfully built medigan
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
from medigan import Generators
generators = Generators()

# %%
# !git clone https://github.com/RichardObi/medigan.git
# Out:
# Cloning into 'medigan'...
# remote: Enumerating objects: 2441, done.
# remote: Counting objects: 100% (756/756), done.
# remote: Compressing objects: 100% (304/304), done.
# remote: Total 2441 (delta 456), reused 597 (delta 411), pack-reused 1685
# Receiving objects: 100% (2441/2441), 108.00 MiB | 30.13 MiB/s, done.
# Resolving deltas: 100% (1471/1471), done.

# %%
cd /content/medigan/examples
# Out:
# /content/medigan/examples

# %%
# !pip install jupyter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.1 MB/s eta 0:00:00
# ...

# %%
import medigan

# Now you can use Medigan functions

# %%
generators.generate(model_id=1, num_samples=3, install_dependencies=True)
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]

# %%
# model 1 is "00001_DCGAN_MMG_CALC_ROI"
gen_function = generators.get_generate_function(model_id=1, num_samples=3)
gen_function()
generators.visualize(1)

# %%
gen_function = generators.get_generate_function(model_id=19, num_samples=3)
gen_function()
generators.visualize(20)
